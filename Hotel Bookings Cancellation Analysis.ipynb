# %% [markdown]
# # Importing Libraries

# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
# Loading the CSV file into pandas Dataframe
df = pd.read_csv(r"C:\Users\ams_j\Desktop\Case_Study\hotel_bookings.csv")

# %% [markdown]
# # Exploratory Data Analysis and Data Cleaning

# %%
# Checking first few rows of the dataframe
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Checking last few rows of the dataframe
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# Checking the shape of the data. It has 119390 rows and 32 columns
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# Checking the columns of the dataset

# %%
# Checking the column names of the data
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Summary information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Changing the data type from object to datetime for the reservation_status_date column
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
# Checking if it worked
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Extract datetime information frome the reservation_status_date column
df.reservation_status_date.dt.year
# Out:
# 0         2015
# 1         2015
# 2         2015
# 3         2015
# 4         2015
#           ...
# 119385    2017
# 119386    2017
# 119387    2017
# 119388    2017
# 119389    2017
# Name: reservation_status_date, Length: 119390, dtype: int64

# %%
# Summary information on the non-numeric columns
df.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
# checking unique values in each column
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique(), '\n')
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
#
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
#
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
#
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'ROU' 'NOR' 'OMN' 'ARG' 'POL' 'DEU'
#  'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST' 'CZE'
#  'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR' 'UKR'
#  'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO' 'ISR'
#  'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM' 'HRV'
#  'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY' 'KWT'
#  'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN' 'SYC'
#  'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB' 'CMR'
#  'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI' 'SAU'
#  'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB' 'NPL'
# ...

# %%
# checking unique values in each column
for col in df.describe().columns:
    print(col)
    print(df[col].unique(), '\n')
# Out:
# is_canceled
# [0 1]
#
# lead_time
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99  95  96  69  45  40  15  36  43  70  16 107  47 113  90
#   50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364 324
#   79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8 100
#   44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112  65
#   67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108 106
#   31  87  41 304 117  59  53  58 116  42 321  38 118  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
#  172 171 145 121 178 305 173 152 354 347 158 185 349 183 352 177 200 192
# ...

# %%
# summary information on the numeric columns
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Checking for columns with missing values
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Dropping columns and rows with missing vaues
df.drop(['agent', 'company'], axis = 1, inplace = True)
df.dropna(inplace = True)

# %%
# Check if it worked
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# summary information on the numeric columns
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Data Analysis and Visualization

# %%
# Total number of bookings after data cleaning
total_bookings = len(df)
total_bookings
# Out:
# 118898

# %%
# Percentage of cancelled bookings
perc_cancelled = df['is_canceled'].value_counts(normalize = True)
perc_cancelled
# Out:
# 0    0.628648
# 1    0.371352
# Name: is_canceled, dtype: float64

# %%
# Creating a bar chart of cancelled bookings
plt.figure(figsize = (6,4))
plt.title('Reservation Status Count', size = 15)
plt.bar(['Not_Cancelled', 'Cancelled'], df['is_canceled'].value_counts())
plt.ylabel('Number of Reservations')

# Display the chart
plt.show()

# %%
# Creating a plot of cancelled bookings in different hotels
plt.figure(figsize = (8,4))
ax1= sns.countplot(x = 'hotel', hue = 'is_canceled', data = df)
legend_labels,_= ax1.get_legend_handles_labels()
plt.title('Reservation Status in Different Hotels', size = 15)
plt.xlabel('Hotel')
plt.ylabel('Number of Reservations')

# Display the chart
plt.show()

# %%
# Percentage of cancelled bookings in Resort Hotels
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
# Percentage of cancelled bookings in City Hotels
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.582911
# 1    0.417089
# Name: is_canceled, dtype: float64

# %%
# Checking the Average Daily Rates on City and Resort Hotels
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
# Creating a plot of Average Daily Rates on City and Resort Hotels
plt.figure(figsize = (20,8))
plt.title('Average Daily Rate in City and Resort Hotel', fontsize = 30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label = 'Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label = 'City Hotel')
plt.legend(fontsize = 15)

# Display the chart
plt.show()

# %%
# Extract month information frome the reservation_status_date column
df['month'] = df['reservation_status_date'].dt.month

# Creating a plot of number of reservations in each month
plt.figure(figsize = (16,8))
ax1= sns.countplot(x = 'month', hue = 'is_canceled', data = df)
legend_labels,_= ax1.get_legend_handles_labels()
plt.title('Reservation Status Per Month', size = 30)
plt.xlabel('Month', size = 15)
plt.ylabel('Number of Reservations', size = 15)
plt.legend(['not cancelled' , 'cancelled'])

# Display the chart
plt.show()

# %%
# Creating a plot of average daily rate in each month
plt.figure(figsize = (16,8))
plt.title('Average Daily Rate Per Month', size = 30)
sns.barplot('month', 'adr', data = df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.xlabel('Month', size = 15)
plt.ylabel('adr', size = 15)

# Display the chart
plt.show()

# %%
# Creating a cancelled_data 
cancelled_data = df[df['is_canceled'] == 1]

# Creating Top 10 Countries with cancelled reservation dataframe
top_10_country = cancelled_data['country'].value_counts().sort_values(ascending = True).tail(10)

# Creating a bar chart of the Top 10 countries with cancelled reservations
plt.figure(figsize=(10, 6))
plt.barh(top_10_country.index, top_10_country.values)
plt.title('Top  10 Countries with Cancelled Reservation ', size = 20)
plt.xlabel('Country')
plt.ylabel('Number of cancelled Reservations ')

# Display the chart
plt.show()

# %%
# Percentage of Top 10 Countries with cancelled reservation
cancelled_data['country'].value_counts(normalize = True)[:10]
# Out:
# PRT    0.623174
# GBR    0.055557
# ESP    0.049306
# FRA    0.043802
# ITA    0.030190
# DEU    0.027586
# IRL    0.018844
# BRA    0.018798
# USA    0.011347
# BEL    0.010735
# Name: country, dtype: float64

# %%
# Calculate number of different market segment
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24160
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
# Percentage of different market segment
df['market_segment'].value_counts(normalize = True)
# Out:
# Online TA        0.474373
# Offline TA/TO    0.203199
# Groups           0.166580
# Direct           0.104695
# Corporate        0.042986
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %%
# Percentage of different market segment with cancelled reservation
cancelled_data['market_segment'].value_counts(normalize = True)
# Out:
# Online TA        0.469685
# Groups           0.273979
# Offline TA/TO    0.187484
# Direct           0.043485
# Corporate        0.022150
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %%
booking_type = cancelled_data['market_segment'].value_counts()

# Creating a plot of different market segment that cancelled reservation
plt.figure(figsize = (8,8))
plt.title('Market Segment', size = 20)
plt.pie(booking_type, autopct = '%.2f', labels = booking_type.index )

plt.show()

# %%
# Creating a cancelled_data with adr dataframe and sorting by reservation_ status_date
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace = True)
cancelled_df_adr.sort_values('reservation_status_date', inplace = True)

# Creating a not_cancelled_data 
not_cancelled_data = df[df['is_canceled'] == 0]

# Creating a not_cancelled_data with adr dataframe and sorting by reservation_ status_date
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace = True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace = True)

# Creating a plot of Average Daily Rates
plt.figure(figsize = (20,6))
plt.title('Average Daily Rate', size = 30)
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label = 'not_cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label = 'cancelled')
plt.legend(fontsize = 15)

# Display the chart
plt.show()

# %%
# Removing inconsistent data - date before 2016
cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr['reservation_status_date'] > '2016') & (cancelled_df_adr['reservation_status_date'] < '2017-09')]
not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date'] > '2016') & (not_cancelled_df_adr['reservation_status_date'] < '2017-09')]

# %%
# Creating a plot of Average Daily Rates of cleaned data
plt.figure(figsize = (20,6))
plt.title('Average Daily Rate', size = 30)
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label = 'not_cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label = 'cancelled')
plt.legend(fontsize = 15)

# Display the chart
plt.show()

# %%
# Calculate number of lead times
df['lead_time'].value_counts()
# Out:
# 0      6223
# 1      3393
# 2      2033
# 3      1802
# 4      1696
#        ...
# 400       1
# 370       1
# 532       1
# 371       1
# 463       1
# Name: lead_time, Length: 479, dtype: int64

# %%
# Calculate average lead_time of cancelled data
cancelled_data['lead_time'].mean()
# Out:
# 144.92530518877538

# %%
# Calculate average lead_time of not_cancelled data
not_cancelled_data['lead_time'].mean()
# Out:
# 80.32020870961269

# %%
# Calculate the average lead time for cancelled bookings
average_lead_time_canceled = cancelled_data['lead_time'].mean()

# Calculate the average lead time for not cancelled bookings
average_lead_time_not_canceled = not_cancelled_data['lead_time'].mean()

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(['Cancelled', 'Not Cancelled'], [average_lead_time_canceled, average_lead_time_not_canceled])
plt.title('Average Lead Time for Cancelled and Not Cancelled Reservations', size = 15)
plt.ylabel('Lead Time (days)')

# Display the plot
plt.show()

# %%
# Create the plot for the relationship between lead time of cancelled and not_cancelled bookings
plt.figure(figsize=(12, 6))
plt.boxplot([cancelled_data['lead_time'], not_cancelled_data['lead_time']])
plt.title('Relationship between Lead Time of Canceled and Non-Canceled Reservations', size = 15)
plt.xticks([1, 2], ['Cancelled', 'Not Cancelled'])
plt.ylabel('Lead Time (days)')

# Display the box plot
plt.show()
